# %%
@@ -1,4 +1,6 @@
# Titanic Exploratory Data Analysis (EDA)  
# Titanic Exploratory Data Analysis (EDA)   

![image](banner.jpg) 
This project focuses on conducting data cleaning and exploratory data analysis (EDA) on the Titanic dataset.The Titanic dataset is a well-known dataset that provides insights into the demographics and survival rates of passengers aboard the Titanic. 

## DATA UNDERSTANDING  
 Binary file addedBIN +53.3 KB 
banner.jpg

  76 changes: 42 additions & 34 deletions76  
notebook.ipynb
Original file line number	Diff line number	Diff line change
@@ -19,6 +19,14 @@
    "# Titanic Exploratory Data Analysis (EDA)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "\n",
    "![image](banner.jpg) "
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
@@ -58,7 +66,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 28,
   "execution_count": 29,
   "metadata": {},
   "outputs": [],
   "source": [
@@ -73,7 +81,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 2,
   "execution_count": 30,
   "metadata": {},
   "outputs": [],
   "source": [
@@ -108,7 +116,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 3,
   "execution_count": 31,
   "metadata": {},
   "outputs": [
    {
@@ -249,7 +257,7 @@
       "4      0            373450   8.0500   NaN        S  "
      ]
     },
     "execution_count": 3,
     "execution_count": 31,
     "metadata": {},
     "output_type": "execute_result"
    }
@@ -262,7 +270,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 4,
   "execution_count": 32,
   "metadata": {},
   "outputs": [],
   "source": [
@@ -272,7 +280,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 5,
   "execution_count": 33,
   "metadata": {},
   "outputs": [
    {
@@ -419,7 +427,7 @@
       "max      6.000000  512.329200  "
      ]
     },
     "execution_count": 5,
     "execution_count": 33,
     "metadata": {},
     "output_type": "execute_result"
    }
@@ -433,7 +441,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 6,
   "execution_count": 34,
   "metadata": {},
   "outputs": [
    {
@@ -476,7 +484,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 7,
   "execution_count": 35,
   "metadata": {},
   "outputs": [
    {
@@ -497,7 +505,7 @@
       "dtype: object"
      ]
     },
     "execution_count": 7,
     "execution_count": 35,
     "metadata": {},
     "output_type": "execute_result"
    }
@@ -509,7 +517,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 8,
   "execution_count": 36,
   "metadata": {},
   "outputs": [
    {
@@ -520,7 +528,7 @@
       "Name: Survived, dtype: int64"
      ]
     },
     "execution_count": 8,
     "execution_count": 36,
     "metadata": {},
     "output_type": "execute_result"
    }
@@ -546,7 +554,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 9,
   "execution_count": 37,
   "metadata": {},
   "outputs": [
    {
@@ -567,7 +575,7 @@
       "dtype: int64"
      ]
     },
     "execution_count": 9,
     "execution_count": 37,
     "metadata": {},
     "output_type": "execute_result"
    }
@@ -593,7 +601,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 10,
   "execution_count": 38,
   "metadata": {},
   "outputs": [],
   "source": [
@@ -610,7 +618,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 11,
   "execution_count": 39,
   "metadata": {},
   "outputs": [],
   "source": [
@@ -622,7 +630,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 12,
   "execution_count": 40,
   "metadata": {},
   "outputs": [],
   "source": [
@@ -639,7 +647,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 13,
   "execution_count": 41,
   "metadata": {},
   "outputs": [
    {
@@ -749,7 +757,7 @@
       " Name: Embarked, dtype: int64}"
      ]
     },
     "execution_count": 13,
     "execution_count": 41,
     "metadata": {},
     "output_type": "execute_result"
    }
@@ -769,7 +777,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 14,
   "execution_count": 42,
   "metadata": {},
   "outputs": [
    {
@@ -778,7 +786,7 @@
       "0"
      ]
     },
     "execution_count": 14,
     "execution_count": 42,
     "metadata": {},
     "output_type": "execute_result"
    }
@@ -797,7 +805,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 15,
   "execution_count": 43,
   "metadata": {},
   "outputs": [],
   "source": [
@@ -806,7 +814,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 16,
   "execution_count": 44,
   "metadata": {},
   "outputs": [
    {
@@ -893,7 +901,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 17,
   "execution_count": 45,
   "metadata": {},
   "outputs": [
    {
@@ -942,7 +950,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 18,
   "execution_count": 46,
   "metadata": {},
   "outputs": [
    {
@@ -986,7 +994,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 19,
   "execution_count": 47,
   "metadata": {},
   "outputs": [
    {
@@ -1036,7 +1044,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 20,
   "execution_count": 48,
   "metadata": {},
   "outputs": [
    {
@@ -4132,7 +4140,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 21,
   "execution_count": 49,
   "metadata": {},
   "outputs": [
    {
@@ -4176,7 +4184,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 22,
   "execution_count": 50,
   "metadata": {},
   "outputs": [
    {
@@ -4219,7 +4227,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 23,
   "execution_count": 51,
   "metadata": {},
   "outputs": [
    {
@@ -4275,7 +4283,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 24,
   "execution_count": 52,
   "metadata": {},
   "outputs": [
    {
@@ -4318,7 +4326,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 25,
   "execution_count": 53,
   "metadata": {},
   "outputs": [
    {
@@ -4351,7 +4359,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 26,
   "execution_count": 54,
   "metadata": {},
   "outputs": [
    {
@@ -4385,7 +4393,7 @@
  },
  {
   "cell_type": "code",
   "execution_count": 27,
   "execution_count": 55,
   "metadata": {},
   "outputs": [
    {
# Out:
#   File <tokenize>:17
#     ]
#     ^
# IndentationError: unindent does not match any outer indentation level
